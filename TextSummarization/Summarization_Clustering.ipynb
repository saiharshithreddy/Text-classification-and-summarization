# %%
import string
import collections
import pandas as pd
import os, glob, sys
 
from nltk import word_tokenize
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from pprint import pprint

# %%
data= pd.read_csv("dataset.csv")
data.head(20)
# Out:
#                                                   URL  CATEGORY  \
# 0   http://www.livemint.com/Politics/H2EvwJSK2VE6O...  business
# 1   http://www.moneynews.com/Economy/federal-reser...  business
# 2   http://www.marketwatch.com/story/feds-plosser-...  business
# 3   http://www.fxstreet.com/news/forex-news/articl...  business
# 4   http://www.iii.co.uk/news-opinion/reuters/news...  business
# 5   http://in.reuters.com/article/2014/03/10/us-ec...  business
# 6   http://blogs.reuters.com/hugo-dixon/2014/03/10...  business
# 7   http://in.reuters.com/article/2014/03/10/eu-ba...  business
# 8   http://in.reuters.com/article/2014/03/10/ecb-p...  business
# 9   http://www.nasdaq.com/article/forex-pound-drop...  business
# 10  http://blogs.wsj.com/brussels/2014/03/10/eu-we...  business
# 11  http://www.fxstreet.com/analysis/strategic-cur...  business
# 12  http://www.businessinsider.com/opening-bell-mo...  business
# 13  http://www.binarytribune.com/2014/03/10/forex-...  business
# 14  http://in.reuters.com/article/2014/03/10/euroz...  business
# 15  http://in.reuters.com/article/2014/03/10/euroz...  business
# 16  http://www.rte.ie/news/business/2014/0310/6012...  business
# 17  http://www.reuters.com/article/2014/03/10/us-e...  business
# 18  http://in.reuters.com/article/2014/03/10/ecb-n...  business
# 19  http://in.reuters.com/article/2014/03/10/ecb-n...  business
#
#                                               CONTENT  \
# 0   Paris/London/Atlanta: Federal Reserve Bank of ...
# 1   Severe winter weather likely affected U.S. job...
# 2   PARISn — The Federal Reserve may have to accel...
# 3   FXStreet (Łódź) - Philadelphia Fed President C...
# 4   The value of international investments may be ...
# 5   BANGALORE (Reuters) - The European Central Ban...
# 6   The European Union’s half-baked banking union ...
# 7   * Countries grapple for deal to prevent embarr...
# 8   FRANKFURT, March 10 (Reuters) - The European C...
# 9   Shutterstock photo\n\nInvesting.com -\n\nInves...
# 10  The European Union’s to-do list isn’t long thi...
# 11  Outlook\n\nAttention is focused on China’s tra...
# 12  Good morning. Here's what you need to know.\n\...
# 13  The euro retreated from highs unseen since Oct...
# 14  By Laura Noonan\n\nDUBLIN, March 10 (Reuters) ...
# 15  * Impairments and ‘hard to value’ assets key a...
# 16  The European Central Bank's stance on how bad ...
# 17  Bank of France Governor Christian Noyer attend...
# 18  * Noyer sees “permanent and deep forces” weigh...
# 19  PARIS, March 10 (Reuters) - French European Ce...
#
#                                               SUMMARY
# 0   Paris/London/Atlanta: Federal Reserve Bank of ...
# 1   Severe winter weather likely affected U.S. job...
# 2   “We must back away from increasing the degree ...
# 3   FXStreet (Łódź) - Philadelphia Fed President C...
# 4   The value of international investments may be ...
# 5   The euro sign landmark is seen at the headquar...
# 6   The European Union’s half-baked banking union ...
# 7   Policymakers agreed last year that the Europea...
# 8   FRANKFURT, March 10 (Reuters) - The European C...
# 9   Shutterstock photoInvesting.com -Investing.com...
# 10  The European Union’s to-do list isn’t long thi...
# 11  As everyone notes repeatedly, you can’t trust ...
# 12  Here's what you need to know.\nImports rose 10...
# 13  “When the euro tends to strengthen, it creates...
# 14  By Laura NoonanDUBLIN, March 10 (Reuters) - Th...
# 15  As well as the initial review on whether banks...
# 16  This is according to three sources with knowle...
# 17  Bank of France Governor Christian Noyer attend...
# 18  Noyer, the governor of the Bank of France, war...
# 19  PARIS, March 10 (Reuters) - French European Ce...

# %%
def process_text(text, stem=True):
    """ Tokenize text and stem words removing punctuation """
    text = text.translate(string.punctuation)
    tokens = word_tokenize(text)
 
    if stem:
        stemmer = PorterStemmer()
        tokens = [stemmer.stem(t) for t in tokens]
 
    return tokens

# %%
def cluster_texts(texts, clusters=3):
    """ Transform texts to Tf-Idf coordinates and cluster texts using K-Means """
    vectorizer = TfidfVectorizer(tokenizer=process_text,
                                 stop_words=stopwords.words('english'),
                                 max_df=0.5,
                                 min_df=0.1,
                                 lowercase=True)
 
    
    tfidf_model = vectorizer.fit_transform(texts)
    km_model = KMeans(n_clusters=clusters)
    km_model.fit(tfidf_model)
 
    clustering = collections.defaultdict(list)
 
    for idx, label in enumerate(km_model.labels_):
        clustering[label].append(idx)
 
    return clustering

# %%
if __name__ == "__main__":
    articles = ["Help"]
    datapath = ['./Data_collection/']
    for document_path in datapath:
        for document_file in glob.glob(os.path.join(document_path, '*.csv')):
            with open(document_file, "r+") as doc:
                inputd = doc.read()
                articles.append(inputd)
                print(inputd)
    clusters = cluster_texts(articles)
    print(dict(clusters))
