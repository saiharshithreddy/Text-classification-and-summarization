# %% [markdown]
# ### Importing Libraries

# %%
import networkx
import rouge
import nltk
import numpy as np
import pandas as pd
from sklearn import preprocessing
import os
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
os.chdir('../Preprocessing')
from normalization import normalize_corpus, parse_content

# %% [markdown]
# ### Reading the Data

# %%
df = pd.read_csv('../Data_collection/dataset.csv')
df.head()
# Out:
#                                                  URL  CATEGORY  \
# 0  http://www.livemint.com/Politics/H2EvwJSK2VE6O...  business
# 1  http://www.moneynews.com/Economy/federal-reser...  business
# 2  http://www.marketwatch.com/story/feds-plosser-...  business
# 3  http://www.fxstreet.com/news/forex-news/articl...  business
# 4  http://www.iii.co.uk/news-opinion/reuters/news...  business
#
#                                              CONTENT  \
# 0  Paris/London/Atlanta: Federal Reserve Bank of ...
# 1  Severe winter weather likely affected U.S. job...
# 2  PARISn — The Federal Reserve may have to accel...
# 3  FXStreet (Łódź) - Philadelphia Fed President C...
# 4  The value of international investments may be ...
#
#                                              SUMMARY
# 0  Paris/London/Atlanta: Federal Reserve Bank of ...
# 1  Severe winter weather likely affected U.S. job...
# 2  “We must back away from increasing the degree ...
# 3  FXStreet (Łódź) - Philadelphia Fed President C...
# 4  The value of international investments may be ...

# %%
df['FILTERED_CONTENT'] = df['CONTENT'].apply(parse_content)
df['length'] =df['FILTERED_CONTENT'].apply(len)
df = df.loc[df['length']>15]
df.drop('length',axis =1 ,inplace =True)

# %%
#Taking a subset of the data:
df=df.iloc[1:1000]

df.head()
# Out:
#                                                   URL  CATEGORY  \
# 5   http://in.reuters.com/article/2014/03/10/us-ec...  business
# 6   http://blogs.reuters.com/hugo-dixon/2014/03/10...  business
# 7   http://in.reuters.com/article/2014/03/10/eu-ba...  business
# 8   http://in.reuters.com/article/2014/03/10/ecb-p...  business
# 11  http://www.fxstreet.com/analysis/strategic-cur...  business
#
#                                               CONTENT  \
# 5   BANGALORE (Reuters) - The European Central Ban...
# 6   The European Union’s half-baked banking union ...
# 7   * Countries grapple for deal to prevent embarr...
# 8   FRANKFURT, March 10 (Reuters) - The European C...
# 11  Outlook\n\nAttention is focused on China’s tra...
#
#                                               SUMMARY  \
# 5   The euro sign landmark is seen at the headquar...
# 6   The European Union’s half-baked banking union ...
# 7   Policymakers agreed last year that the Europea...
# 8   FRANKFURT, March 10 (Reuters) - The European C...
# 11  As everyone notes repeatedly, you can’t trust ...
#
#                                      FILTERED_CONTENT
# 5   [BANGALORE (Reuters) - The European Central Ba...
# 6   [The European Union’s half-baked banking union...
# 7   [* Countries grapple for deal to prevent embar...
# 8   [FRANKFURT, March 10 (Reuters) - The European ...
# 11  [Outlook, Attention is focused on China’s trad...

# %%
df['FILTERED_CONTENT'] = df['FILTERED_CONTENT'].apply(normalize_corpus)
df.head()
# Out:
#                                                   URL  CATEGORY  \
# 5   http://in.reuters.com/article/2014/03/10/us-ec...  business
# 6   http://blogs.reuters.com/hugo-dixon/2014/03/10...  business
# 7   http://in.reuters.com/article/2014/03/10/eu-ba...  business
# 8   http://in.reuters.com/article/2014/03/10/ecb-p...  business
# 11  http://www.fxstreet.com/analysis/strategic-cur...  business
#
#                                               CONTENT  \
# 5   BANGALORE (Reuters) - The European Central Ban...
# 6   The European Union’s half-baked banking union ...
# 7   * Countries grapple for deal to prevent embarr...
# 8   FRANKFURT, March 10 (Reuters) - The European C...
# 11  Outlook\n\nAttention is focused on China’s tra...
#
#                                               SUMMARY  \
# 5   The euro sign landmark is seen at the headquar...
# 6   The European Union’s half-baked banking union ...
# 7   Policymakers agreed last year that the Europea...
# 8   FRANKFURT, March 10 (Reuters) - The European C...
# 11  As everyone notes repeatedly, you can’t trust ...
#
#                                      FILTERED_CONTENT
# 5   [bangalore reuters the european central bank s...
# 6   [the european union banking union could make w...
# 7   [countries grapple deal prevent embarrassing d...
# 8   [frankfurt march reuters the european central ...
# 11  [outlook, attention focus china trade deficit ...

# %% [markdown]
# ### Text Rank Algorithm

# %%
def textrank_text_summarizer(data):
    
    text =data[4]
    sentences = [sent for sent in nltk.sent_tokenize(data[2])]
    summary = [sent for sent in nltk.sent_tokenize(data[3])]
    num_sentences = len(summary)
    bow_matrix = CountVectorizer().fit_transform(text)

    dt_matrix = TfidfTransformer().fit_transform(bow_matrix)

    similarity_matrix = (dt_matrix * dt_matrix.T)
    similarity_graph = networkx.from_scipy_sparse_matrix(similarity_matrix)
    
    scores = networkx.pagerank(similarity_graph)   
    ranked_sentences = sorted(((score, index) 
                                for index, score 
                                in scores.items()), 
                              reverse=True)
    try:
        top_sentence_indices = [ranked_sentences[index][1] for index in range(num_sentences)]
        top_sentence_indices.sort()
        top_sentences = [sentences[index] for index in top_sentence_indices]
        summary =''.join(top_sentences)
        return summary
    except IndexError:
        pass

# %%
df['Generated_Summary']= df.apply(textrank_text_summarizer,axis =1)
df.dropna(subset = ['Generated_Summary'],inplace=True)
df.head(10)
# Out:
#                                                   URL  CATEGORY  \
# 5   http://in.reuters.com/article/2014/03/10/us-ec...  business
# 6   http://blogs.reuters.com/hugo-dixon/2014/03/10...  business
# 7   http://in.reuters.com/article/2014/03/10/eu-ba...  business
# 8   http://in.reuters.com/article/2014/03/10/ecb-p...  business
# 11  http://www.fxstreet.com/analysis/strategic-cur...  business
# 12  http://www.businessinsider.com/opening-bell-mo...  business
# 15  http://in.reuters.com/article/2014/03/10/euroz...  business
# 16  http://www.rte.ie/news/business/2014/0310/6012...  business
# 18  http://in.reuters.com/article/2014/03/10/ecb-n...  business
# 20  http://www.marketwatch.com/story/ecbs-noyer-lo...  business
#
#                                               CONTENT  \
# 5   BANGALORE (Reuters) - The European Central Ban...
# 6   The European Union’s half-baked banking union ...
# 7   * Countries grapple for deal to prevent embarr...
# 8   FRANKFURT, March 10 (Reuters) - The European C...
# 11  Outlook\n\nAttention is focused on China’s tra...
# 12  Good morning. Here's what you need to know.\n\...
# 15  * Impairments and ‘hard to value’ assets key a...
# 16  The European Central Bank's stance on how bad ...
# 18  * Noyer sees “permanent and deep forces” weigh...
# 20  PARIS--The slow pace of price increases and no...
#
#                                               SUMMARY  \
# 5   The euro sign landmark is seen at the headquar...
# 6   The European Union’s half-baked banking union ...
# 7   Policymakers agreed last year that the Europea...
# 8   FRANKFURT, March 10 (Reuters) - The European C...
# 11  As everyone notes repeatedly, you can’t trust ...
# 12  Here's what you need to know.\nImports rose 10...
# 15  As well as the initial review on whether banks...
# 16  This is according to three sources with knowle...
# 18  Noyer, the governor of the Bank of France, war...
# 20  "The euro area needs such adjustments in order...
#
#                                      FILTERED_CONTENT  \
# 5   [bangalore reuters the european central bank s...
# 6   [the european union banking union could make w...
# 7   [countries grapple deal prevent embarrassing d...
# 8   [frankfurt march reuters the european central ...
# 11  [outlook, attention focus china trade deficit ...
# 12  [good morning, here need know, chinese export ...
# 15  [impairments hard value asset key area, loan p...
# 16  [the european central bank stance bad loan def...
# 18  [noyer see permanent deep force weigh inflatio...
# 20  [paris the slow pace price increase nominal wa...
#
#                                     Generated_Summary
# 5   BANGALORE (Reuters) - The European Central Ban...
# 6   The European Union’s half-baked banking union ...
# 7   Failure to do so would delay the law by at lea...
# 8   FRANKFURT, March 10 (Reuters) - The European C...
# 11  The PBOC target is 3.5%, by the way.Suppliers ...
# 12  Chinese exports fell 18.1% from a year earlier...
# 15  As well as the initial review on whether banks...
# 16  The European Central Bank's stance on how bad ...
# 18  * Noyer sees “permanent and deep forces” weigh...
# 20  PARIS--The slow pace of price increases and no...

# %% [markdown]
# #### Results

# %%
hypothesis = df['Generated_Summary'].tolist()
reference = df['SUMMARY'].tolist()

def prepare_results(p, r, f):
    return '\t{}:\t{}: {:5.2f}\t{}: {:5.2f}\t{}: {:5.2f}'.format(metric, 'P', 100.0 * p, 'R', 100.0 * r, 'F1', 100.0 * f)


for aggregator in ['Avg','Best']:
    print('Evaluation with {}'.format(aggregator))
    apply_avg = aggregator == 'Avg'
    apply_best = aggregator == 'Best'

    evaluator = rouge.Rouge(metrics=['rouge-n'],
                           max_n=4,
                           limit_length=True,
                           length_limit=100,
                           length_limit_type='words',
                           apply_avg=apply_avg,
                           apply_best=apply_best,
                           alpha=0.5, # Default F1_score
                           weight_factor=1.2,
                           stemming=True)

    scores = evaluator.get_scores(hypothesis, reference)
    for metric, results in sorted(scores.items(), key=lambda x: x[0]):
        print(prepare_results(results['p'], results['r'], results['f']))
    print()
# Out:
# Evaluation with Avg
# 	rouge-1:	P: 52.49	R: 51.07	F1: 51.13
# 	rouge-2:	P: 35.90	R: 35.15	F1: 35.17
# 	rouge-3:	P: 32.63	R: 31.95	F1: 31.97
# 	rouge-4:	P: 31.11	R: 30.48	F1: 30.49
#
# Evaluation with Best
# 	rouge-1:	P: 52.49	R: 51.07	F1: 51.13
# 	rouge-2:	P: 35.90	R: 35.15	F1: 35.17
# 	rouge-3:	P: 32.63	R: 31.95	F1: 31.97
# 	rouge-4:	P: 31.11	R: 30.48	F1: 30.49
